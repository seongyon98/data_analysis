# %% [markdown]
# ### 원본 데이터 "olist_orders_dataset" 데이터 전처리 후 새로운 데이터 "sorted_orders_dataset" 에서 필요없는 컬럼 제거

# %%
##  데이터 불러오기
import pandas as pd

sorted_orders = pd.read_csv('sorted_orders_dataset.csv')

# %%
sorted_orders
# Out:
#        Unnamed: 0                          order_id  \
# 0               0  e481f51cbdc54678b7cc49136f2d6af7
# 1               1  53cdb2fc8bc7dce0b6741e2150273451
# 2               2  47770eb9100c2d0c44946d9cf07ec65d
# 3               3  949d5b44dbf5de918fe9c16f97b45f8a
# 4               4  ad21c59c0840e6cb83a9ceb5573f8159
# ...           ...                               ...
# 96450       99436  9c5dedf39a927c1b2549525ed64a053c
# 96451       99437  63943bddc261676b46f01ca7ac2f7bd8
# 96452       99438  83c1379a015df1e13d02aae0204711ab
# 96453       99439  11c177c8e97725db2631073c19f07b62
# 96454       99440  66dea50a8b16d9b4dee7af250b4be1a5
#
#                             customer_id order_status order_purchase_timestamp  \
# 0      9ef432eb6251297304e76186b10a928d    delivered      2017-10-02 10:56:33
# 1      b0830fb4747a6c6d20dea0b8c802d7ef    delivered      2018-07-24 20:41:37
# 2      41ce2a54c0b03bf3443c3d931a367089    delivered      2018-08-08 08:38:49
# ...

# %%
sorted_orders2 = sorted_orders.drop(['Unnamed: 0','order_status', 'order_purchase_timestamp','order_approved_at','order_delivered_carrier_date', 'order_delivered_customer_date', 'order_estimated_delivery_date'], axis=1)

# %%
sorted_orders2
# Out:
#                                order_id                       customer_id
# 0      e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1      53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2      47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3      949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4      ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                 ...                               ...
# 96450  9c5dedf39a927c1b2549525ed64a053c  39bd1228ee8140590ac3aca26f2dfe00
# 96451  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 96452  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 96453  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 96454  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
# [96455 rows x 2 columns]

# %%
def save_dataframe(dataframe: pd.DataFrame):
    dataframe.to_csv("sorted_orders2.csv",index=False)

save_dataframe(sorted_orders2)

# %%
import pandas as pd

sorted_final = pd.read_csv('sorted_orders2_dataset_final.csv')

# %%
sorted_final
# Out:
#                                order_id                       customer_id
# 0      e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1      53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2      47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3      949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4      ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                 ...                               ...
# 96450  9c5dedf39a927c1b2549525ed64a053c  39bd1228ee8140590ac3aca26f2dfe00
# 96451  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 96452  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 96453  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 96454  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
# [96455 rows x 2 columns]
